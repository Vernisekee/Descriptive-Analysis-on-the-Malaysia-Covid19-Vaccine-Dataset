# %% [markdown]
# #Vaccincation Rate

# %% [markdown]
# ##National

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import dataset 
url = 'https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/vaccination/vax_malaysia.csv'
Vax_MY_dataset = pd.read_csv(url)

#View the first 5 rows 
Vax_MY_dataset.head()
# Out:
#          date  daily_partial  daily_full  ...  pending1  pending2  pending3
# 0  2021-02-24             63           3  ...         1         0         0
# 1  2021-02-25           1149           2  ...         2         0         0
# 2  2021-02-26           4067           3  ...         7         0         0
# 3  2021-02-27           6710           6  ...        18         0         0
# 4  2021-02-28           6715           5  ...         4         0         0
#
# [5 rows x 30 columns]

# %%
#View the last 5 rows 
Vax_MY_dataset.tail()
# Out:
#            date  daily_partial  daily_full  ...  pending1  pending2  pending3
# 321  2022-01-11           2163        3193  ...         0         2         2
# 322  2022-01-12           2019        3205  ...         0         2        10
# 323  2022-01-13           2168        3480  ...         1         6        43
# 324  2022-01-14           1745        2237  ...        28         0        47
# 325  2022-01-15            985         897  ...        10        11      1848
#
# [5 rows x 30 columns]

# %%
#View the data types,columns, null value counts etc
Vax_MY_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326 entries, 0 to 325
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 326 non-null    object
#  1   daily_partial        326 non-null    int64
#  2   daily_full           326 non-null    int64
#  3   daily                326 non-null    int64
#  4   daily_partial_child  326 non-null    int64
#  5   daily_full_child     326 non-null    int64
#  6   daily_booster        326 non-null    int64
#  7   cumul_partial        326 non-null    int64
#  8   cumul_full           326 non-null    int64
#  9   cumul                326 non-null    int64
#  10  cumul_partial_child  326 non-null    int64
#  11  cumul_full_child     326 non-null    int64
#  12  cumul_booster        326 non-null    int64
#  13  pfizer1              326 non-null    int64
#  14  pfizer2              326 non-null    int64
# ...

# %%
#View the dimensions of the dataset
print("Vaccination national data set dimensions : {}".format(Vax_MY_dataset.shape))
# Out:
# Vaccination national data set dimensions : (326, 30)

# %%
#View the basic statistic details about the data of the dataset
Vax_MY_dataset.describe().T
# Out:
#                      count          mean  ...          75%         max
# daily_partial        326.0  7.926891e+04  ...    145298.75    375290.0
# daily_full           326.0  7.875988e+04  ...    152862.25    364829.0
# daily                326.0  1.862873e+05  ...    273203.75    582528.0
# daily_partial_child  326.0  8.776828e+03  ...      1874.50    175080.0
# daily_full_child     326.0  8.506942e+03  ...      1868.50    183762.0
# daily_booster        326.0  2.825853e+04  ...     21049.00    261711.0
# cumul_partial        326.0  1.365710e+07  ...  25638198.75  26044184.0
# cumul_full           326.0  1.156315e+07  ...  24336742.75  25675722.0
# cumul                326.0  2.604278e+07  ...  49944976.75  60729670.0
# cumul_partial_child  326.0  9.358665e+05  ...   2710854.50   2861246.0
# cumul_full_child     326.0  7.261653e+05  ...   1939033.25   2773263.0
# cumul_booster        326.0  8.921829e+05  ...    147989.25   9212282.0
# ...

# %%
#find the sum of NA
Vax_MY_dataset.isnull().sum()
# Out:
# date                   0
# daily_partial          0
# daily_full             0
# daily                  0
# daily_partial_child    0
# daily_full_child       0
# daily_booster          0
# cumul_partial          0
# cumul_full             0
# cumul                  0
# cumul_partial_child    0
# cumul_full_child       0
# cumul_booster          0
# pfizer1                0
# pfizer2                0
# pfizer3                0
# sinovac1               0
# sinovac2               0
# sinovac3               0
# astra1                 0
# astra2                 0
# astra3                 0
# sinopharm1             0
# sinopharm2             0
# sinopharm3             0
# cansino                0
# cansino3               0
# pending1               0
# pending2               0
# pending3               0
# dtype: int64

# %%
#Format the date for data visualisation
Vax_MY_dataset['date'] = pd.to_datetime(Vax_MY_dataset['date'], format="%Y/%m/%d")

# %%
#Daily number of vaccine administration
plt.figure(figsize=(10,7))
plt.plot(Vax_MY_dataset.date,Vax_MY_dataset.daily_partial, color='m', label='Partial')
plt.plot(Vax_MY_dataset.date,Vax_MY_dataset.daily_full, color='salmon', label='Full')
plt.plot(Vax_MY_dataset.date,Vax_MY_dataset.daily_booster, color='r', label='Booster')
plt.plot(Vax_MY_dataset.date,Vax_MY_dataset.daily, color='c', label='Total')
plt.title("Vaccination (National)", fontsize=25, fontweight=10, color='red')
plt.xlabel("Date", fontsize = 20)
plt.ylabel("Daily Vaccine Administration", fontsize = 20)
plt.legend(loc='upper right')
plt.show()

# %%
#total partial, full, booster and sum of all vaccine doses administered on the latest date (cut-off date 11/1/2022)
Vax_MY_dataset.iloc[-1, [1, 2, 6, 3]].plot(kind="bar")
plt.title("Total Vaccination For All dose 11/1/2022")
plt.xlabel("Dose")
plt.ylabel("Total Vaccine Administration")
dose = ('Partial','Full','Booster','Total')
x_pos = np.arange(len(dose))
plt.xticks(x_pos, dose)
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

#Input data labels 
y = Vax_MY_dataset.iloc[-1, [1, 2, 6, 3]]
x = ['Partial','Full','Booster','Total']
for i in range(len(x)):
  plt.text(i, y[i], y[i], ha='center', va='bottom')

plt.show()

# %%
#Daily cumulative total for partial, full, booster and total vaccines administered
plt.figure(figsize=(10,7))
plt.plot(Vax_MY_dataset.date,Vax_MY_dataset.cumul_partial, color='m', label='Partial')
plt.plot(Vax_MY_dataset.date,Vax_MY_dataset.cumul_full, color='salmon', label='Full')
plt.plot(Vax_MY_dataset.date,Vax_MY_dataset.cumul_booster, color='r', label='Booster')
plt.plot(Vax_MY_dataset.date,Vax_MY_dataset.cumul, color='c', label='Total')
plt.title("Vaccination (National)", fontsize=25, fontweight=10, color='red')
plt.xlabel("Date", fontsize = 20)
plt.ylabel("Cumulative Vaccine Administration", fontsize = 20)
plt.legend(loc='upper right')
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.show()

# %%
#Cumulative total for partial, full, booster and total vaccines administered on the latest date (cut-off date 11/1/2022)
Vax_MY_dataset.iloc[-1, [7, 8, 12, 9]].plot(kind="bar")
plt.title("Vaccination For All dose (Cumulative)")
plt.xlabel("Dose")
plt.ylabel("Cumulative Vaccine Administration")
dose = ('Partial','Full','Booster', 'Total')
x_pos = np.arange(len(dose))
plt.xticks(x_pos, dose)
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

#Input data labels 
y = Vax_MY_dataset.iloc[-1, [7, 8, 12, 9]]
x = ['Partial','Full', 'Booster', 'Total']
for i in range(len(x)):
  plt.text(i, y[i], y[i], ha='center', va='bottom')

plt.show()

# %%
#Total vaccine administered for each dose and vaccine type
x = ['Pfizer', 'Sinovac', 'Astra', 'Sinopharm']
dose1 = np.array(Vax_MY_dataset.iloc[:, [13,16,19,22]].sum())
dose2 = np.array(Vax_MY_dataset.iloc[:, [14,17,20,23]].sum())
dose3 = np.array(Vax_MY_dataset.iloc[:, [15,18,21,24]].sum())
plt.bar(x, dose1, color='r')
plt.bar(x, dose2, bottom=dose1, color='b')
plt.bar(x, dose3, bottom=dose1+dose2, color='y')
plt.xlabel("Vaccine Type")
plt.ylabel("Total Vaccine Administered")
plt.legend(['Dose 1', 'Dose 2', 'Dose 3'])
plt.title("Total Vaccine Administered")
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

#Input data labels 
y = [Pfizer, Sinovac, Astra, Sinopharm]
for i in range(len(x)):
  plt.text(i, y[i], y[i], ha='center', va='bottom')

plt.show()

# %% [markdown]
# ##State

# %%
url = 'https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/vaccination/vax_state.csv'
states = pd.read_csv(url)
states
# Out:
#             date              state  ...  pending2  pending3
# 0     2021-02-24              Johor  ...         0         0
# 1     2021-02-24              Kedah  ...         0         0
# 2     2021-02-24           Kelantan  ...         0         0
# 3     2021-02-24             Melaka  ...         0         0
# 4     2021-02-24    Negeri Sembilan  ...         0         0
# ...          ...                ...  ...       ...       ...
# 5227  2022-01-16           Selangor  ...         3       509
# 5228  2022-01-16         Terengganu  ...         0        56
# 5229  2022-01-16  W.P. Kuala Lumpur  ...         0       272
# 5230  2022-01-16        W.P. Labuan  ...         0         0
# 5231  2022-01-16     W.P. Putrajaya  ...         0         4
#
# [5232 rows x 31 columns]

# %%
states.describe()
# Out:
#        daily_partial     daily_full  ...     pending2     pending3
# count    5232.000000    5232.000000  ...  5232.000000  5232.000000
# mean     4939.380161    4907.721713  ...     1.349962     0.672401
# std     10080.836257    9911.493741  ...    10.030466     9.633332
# min         0.000000       0.000000  ...     0.000000     0.000000
# 25%       151.000000      92.000000  ...     0.000000     0.000000
# 50%       887.000000     862.000000  ...     0.000000     0.000000
# 75%      5125.500000    5032.500000  ...     0.000000     0.000000
# max    110440.000000  110866.000000  ...   374.000000   509.000000
#
# [8 rows x 29 columns]

# %%
states.isnull().sum()
# Out:
# date                   0
# state                  0
# daily_partial          0
# daily_full             0
# daily                  0
# daily_partial_child    0
# daily_full_child       0
# daily_booster          0
# cumul_partial          0
# cumul_full             0
# cumul                  0
# cumul_partial_child    0
# cumul_full_child       0
# cumul_booster          0
# pfizer1                0
# pfizer2                0
# pfizer3                0
# sinovac1               0
# sinovac2               0
# sinovac3               0
# astra1                 0
# astra2                 0
# astra3                 0
# sinopharm1             0
# sinopharm2             0
# sinopharm3             0
# cansino                0
# cansino3               0
# pending1               0
# pending2               0
# pending3               0
# dtype: int64

# %%
states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5232 entries, 0 to 5231
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 5232 non-null   object
#  1   state                5232 non-null   object
#  2   daily_partial        5232 non-null   int64
#  3   daily_full           5232 non-null   int64
#  4   daily                5232 non-null   int64
#  5   daily_partial_child  5232 non-null   int64
#  6   daily_full_child     5232 non-null   int64
#  7   daily_booster        5232 non-null   int64
#  8   cumul_partial        5232 non-null   int64
#  9   cumul_full           5232 non-null   int64
#  10  cumul                5232 non-null   int64
#  11  cumul_partial_child  5232 non-null   int64
#  12  cumul_full_child     5232 non-null   int64
#  13  cumul_booster        5232 non-null   int64
#  14  pfizer1              5232 non-null   int64
# ...

# %%
df_group = states.groupby(['state']).sum().sort_values(['cumul_full'],ascending=False)
df_group
# Out:
#                    daily_partial  daily_full  ...  pending2  pending3
# state                                         ...
# Selangor                 4835492     4780091  ...       414      1016
# W.P. Kuala Lumpur        3056713     3028322  ...       276       483
# Johor                    3075928     3048129  ...       347       503
# Sarawak                  2176077     2132269  ...      3062       192
# Sabah                    2324124     2395340  ...      1292       104
# Perak                    1872473     1859457  ...       230       126
# Kedah                    1585928     1574697  ...       225       302
# Pulau Pinang             1534285     1524798  ...        65       318
# Pahang                   1183362     1176961  ...       282       106
# Kelantan                 1193518     1178467  ...       127        63
# Negeri Sembilan           956154      949707  ...       431        72
# Terengganu                888765      880551  ...       153        96
# ...

# %%
population =pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/static/population.csv')
pop=population.drop(index=0)
pop.sort_values(['pop'],ascending=False)
# Out:
#                 state  idxs      pop   pop_18  pop_60  pop_12
# 10           Selangor    10  6538000  4747900  575800  569100
# 12              Sabah    12  3908500  2758400  238900  434000
# 1               Johor     1  3781000  2711900  428700  359900
# 13            Sarawak    13  2816500  2042700  332800  293200
# 8               Perak     8  2510300  1862700  397300  237200
# 2               Kedah     2  2185100  1540600  272500  211400
# 3            Kelantan     3  1906700  1236200  194100  210600
# 14  W.P. Kuala Lumpur    14  1773700  1348600  205800  140800
# 7        Pulau Pinang     7  1773600  1367200  239200  141500
# 6              Pahang     6  1678700  1175800  190200  173000
# 11         Terengganu    11  1259300   808400  115200  138100
# 5     Negeri Sembilan     5  1128800   814400  145000  109400
# 4              Melaka     4   932700   677400  118500   86500
# 9              Perlis     9   254900   181200   35100   23100
# ...

# %%
pop.describe()
# Out:
#             idxs           pop        pop_18         pop_60         pop_12
# count  16.000000  1.600000e+01  1.600000e+01      16.000000      16.000000
# mean    8.500000  2.041088e+06  1.463100e+06  218875.000000  196718.750000
# std     4.760952  1.657956e+06  1.202421e+06  157446.395111  155538.840674
# min     1.000000  9.960000e+04  6.770000e+04    5000.000000    9500.000000
# 25%     4.750000  1.079775e+06  7.756500e+05  117675.000000  103675.000000
# 50%     8.500000  1.773650e+06  1.292400e+06  199950.000000  157250.000000
# 75%    12.250000  2.586850e+06  1.907700e+06  287575.000000  251200.000000
# max    16.000000  6.538000e+06  4.747900e+06  575800.000000  569100.000000

# %%
pop.isnull().sum()
# Out:
# state     0
# idxs      0
# pop       0
# pop_18    0
# pop_60    0
# pop_12    0
# dtype: int64

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 1 to 16
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   state   16 non-null     object
#  1   idxs    16 non-null     int64
#  2   pop     16 non-null     int64
#  3   pop_18  16 non-null     int64
#  4   pop_60  16 non-null     int64
#  5   pop_12  16 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 896.0+ bytes

# %%
states_cases =pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/cases_state.csv')

# %%
df_state = states_cases.groupby(['state']).sum().sort_values(['cases_new'],ascending=False)
df_state
# Out:
#                    cases_new  cases_import  ...  cases_70_79  cases_80
# state                                       ...
# Selangor              799787          3214  ...        12886      4129
# Sarawak               252600           326  ...         9517      3698
# Johor                 250780          1130  ...         5335      2032
# Sabah                 244217           303  ...         5328      2290
# W.P. Kuala Lumpur     214829          4231  ...         5142      1859
# Kelantan              173557           515  ...         5922      1721
# Kedah                 171828           546  ...         4177      1490
# Pulau Pinang          164165           358  ...         4598      1960
# Perak                 131167           530  ...         4540      1656
# Negeri Sembilan       115717           749  ...         2302       880
# Pahang                 98567           298  ...         2268       650
# Terengganu             84290           303  ...         2541       721
# ...

# %%
#Full vaccination for each state
df_group['daily_full'].plot(kind='bar',width=0.8,figsize=(20,10))
plt.xlabel('State')
plt.ylabel('Full Vaccination')
plt.title('Full Vaccination for each state',fontsize=20)
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

for index,data in enumerate(df_group['daily_full']):
  plt.text(x=index , y =data, s=f"{data}" , fontdict=dict(fontsize=10),ha='center')

plt.show()

# %%
#Booster
df_group['daily_booster'].plot(kind='bar',width=0.8,figsize=(20,10))
plt.xlabel('State')
plt.ylabel('Booster')
plt.title('Booster of each state',fontsize=20)
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

for index,data in enumerate(df_group['daily_booster']):
  plt.text(x=index , y =data, s=f"{data}" , fontdict=dict(fontsize=10),ha='center')

plt.show()

# %%
#Partial vaccination
df_group['daily_partial'].plot(kind='bar',width=0.8,figsize=(20,10))
plt.xlabel('state')
plt.ylabel('Partial Vaccination')
plt.title('Partial Vaccination of each state',fontsize=20)
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

for index,data in enumerate(df_group['daily_partial']):
  plt.text(x=index , y =data , s=f"{data}" , fontdict=dict(fontsize=10),ha='center')

plt.show()

# %%
df_group[['daily_partial','daily_full','daily_booster']].plot(kind='bar', stacked='true',width=0.8,figsize=(20,10))
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.title('Overview vaccination status on each states',fontsize=20)
plt.legend(loc='center right',fontsize=15)

for index,data in enumerate(df_group['daily_partial']+df_group['daily_full']+df_group['daily_booster']):
  plt.text(x=index , y =data , s=f"{data}" , fontdict=dict(fontsize=10),ha='center')

plt.show()

# %%
df_state['cases_new'].plot(kind = 'bar',width=0.8, figsize=(20,10))
plt.title('Total new cases of each state',fontsize=20)

for index,data in enumerate(df_state['cases_new']):
  plt.text(x=index , y =data+3 , s=f"{data}",fontdict=dict(fontsize=10), ha='center')

# %%
a=df_group.groupby('state')['daily_full'].sum()
a=pd.DataFrame(a)
 
b=df_group.groupby('state')['daily_booster'].sum()
b=pd.DataFrame(b)
 
c=df_group.groupby('state')['daily_partial'].sum()
c=pd.DataFrame(c)
 
new = pd.concat([a,b,c],axis=1)
new
 
new['population']=[3781000,2185100,1906700,932700,1128800,1678700,2510300,254900,1773600,3908500,2816500,6538000,1259300,1773700,99600,110000]
new
 
new['percentage_full']=(new['daily_full']/new['population'])*100
new['percentage_booster']=(new['daily_booster']/new['population'])*100
new['percentage_partial']=(new['daily_partial']/new['population'])*100
new
# Out:
#                    daily_full  ...  percentage_partial
# state                          ...
# Johor                 3048129  ...           81.352235
# Kedah                 1574697  ...           72.579195
# Kelantan              1178467  ...           62.596004
# Melaka                 716835  ...           77.306101
# Negeri Sembilan        949707  ...           84.705351
# Pahang                1176961  ...           70.492762
# Perak                 1859457  ...           74.591603
# Perlis                 204543  ...           80.776383
# Pulau Pinang          1524798  ...           86.506822
# Sabah                 2395340  ...           59.463324
# Sarawak               2132269  ...           77.261743
# Selangor              4780091  ...           73.959804
# Terengganu             880551  ...           70.576114
# W.P. Kuala Lumpur     3028322  ...          172.335401
# W.P. Labuan             79824  ...           83.217871
# ...

# %%
plt.figure(figsize=(25,10))

w=0.3

bar1=np.arange(len(new['state']))
bar2=[i+w for i in bar1]
bar3=[i+w for i in bar2]

plt.bar(bar1,new['percentage_partial'],w,label='Partial vaccination')
plt.bar(bar2,new['percentage_full'],w,label='Full vaccination')
plt.bar(bar3,new['percentage_booster'],w,label='booster')
plt.xlabel('State')
plt.ylabel('Percentage (%)')
plt.title('Percentage of vaccination')
plt.xticks(bar2,new['state'])
plt.legend(loc='upper center')

plt.show()

# %% [markdown]
# #Type of Vaccine

# %%
Vactype = states[:4559][['state','pfizer1','sinovac1','astra1','sinopharm1']]
print(Vactype)
Vactype.groupby('state').sum()
States = Vactype.iloc[:,0]
Pfizer1stdose = Vactype.iloc[:,1]
Sinovac1stdose = Vactype.iloc[:,2]
AstraZaneca1stdose = Vactype.iloc[:,3]
Sinopharm1stdose = Vactype.iloc[:,4]
index = np.arange(len(States))
# Out:
#                   state  pfizer1  sinovac1  astra1  sinopharm1
# 0                 Johor        0         0       0           0
# 1                 Kedah        0         0       0           0
# 2              Kelantan        0         0       0           0
# 3                Melaka        0         0       0           0
# 4       Negeri Sembilan        0         0       0           0
# ...                 ...      ...       ...     ...         ...
# 4554            Sarawak      107         5       0           0
# 4555           Selangor      186       143       0          34
# 4556         Terengganu      104        13       0           0
# 4557  W.P. Kuala Lumpur       52        49       6           2
# 4558        W.P. Labuan        0         0       0           0
#
# [4559 rows x 5 columns]

# %%
Vactype.groupby(['state']).sum().iloc[:, 0:6].plot.bar(stacked=True).legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
Vactype = states[:4559][['state','pfizer2','sinovac2','astra2','sinopharm2','cansino','pending2']]
print(Vactype)
Vactype.groupby('state').describe()
Vactype.groupby('state').sum()
States = Vactype.iloc[:,0]
Pfizer = Vactype.iloc[:,1]
Sinovac = Vactype.iloc[:,2]
AstraZaneca = Vactype.iloc[:,3]
Sinopharm = Vactype.iloc[:,4]
Cansino = Vactype.iloc[:,5]
index = np.arange(len(States))
# Out:
#                   state  pfizer2  sinovac2  ...  sinopharm2  cansino  pending2
# 0                 Johor        0         0  ...           0        0         0
# 1                 Kedah        0         0  ...           0        0         0
# 2              Kelantan        0         0  ...           0        0         0
# 3                Melaka        0         0  ...           0        0         0
# 4       Negeri Sembilan        0         0  ...           0        0         0
# ...                 ...      ...       ...  ...         ...      ...       ...
# 4554            Sarawak      175         1  ...           0        0         0
# 4555           Selangor      150       151  ...          34        0         0
# 4556         Terengganu      200        30  ...           0        2         0
# 4557  W.P. Kuala Lumpur      191        55  ...           8        6         0
# 4558        W.P. Labuan        0         0  ...           0        0         0
#
# [4559 rows x 7 columns]

# %%
Vactype.groupby(['state']).sum().iloc[:, 0:6].plot.bar(stacked=True).legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# #COVID19 Vaccine Adverse Event Following Immunization (AEFI)

# %%
#import dataset 
url = 'https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/vaccination/aefi.csv'
Vax_aefi_dataset = pd.read_csv(url)

#View the first 5 rows
Vax_aefi_dataset.head()
# Out:
#          date vaxtype  daily_total  ...  d2_vomiting  d2_chills  d2_rash
# 0  2021-02-25  pfizer            1  ...            0          0        0
# 1  2021-02-26  pfizer            2  ...            0          0        0
# 2  2021-02-27  pfizer            4  ...            0          0        0
# 3  2021-02-28  pfizer           12  ...            0          0        0
# 4  2021-03-01  pfizer           33  ...            0          0        0
#
# [5 rows x 32 columns]

# %%
#View the last 5 rows  
Vax_aefi_dataset.tail()
# Out:
#            date      vaxtype  daily_total  ...  d2_vomiting  d2_chills  d2_rash
# 932  2022-01-11      sinovac            6  ...            0          0        0
# 933  2022-01-12  astrazeneca            0  ...            0          0        0
# 934  2022-01-12       pfizer           30  ...            0          0        0
# 935  2022-01-12    sinopharm            0  ...            0          0        0
# 936  2022-01-12      sinovac            2  ...            0          0        0
#
# [5 rows x 32 columns]

# %%
#View the data types,columns, null value counts etc
Vax_aefi_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 937 entries, 0 to 936
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         937 non-null    object
#  1   vaxtype                      937 non-null    object
#  2   daily_total                  937 non-null    int64
#  3   daily_serious_npra           937 non-null    int64
#  4   daily_nonserious             937 non-null    int64
#  5   daily_nonserious_npra        937 non-null    int64
#  6   daily_nonserious_mysj_dose1  937 non-null    int64
#  7   daily_nonserious_mysj_dose2  937 non-null    int64
#  8   d1_site_pain                 937 non-null    int64
#  9   d1_site_swelling             937 non-null    int64
#  10  d1_site_redness              937 non-null    int64
#  11  d1_tiredness                 937 non-null    int64
#  12  d1_headache                  937 non-null    int64
# ...

# %%
#View the dimensions of the dataset
print("Vaccination aefi data set dimensions : {}".format(Vax_aefi_dataset.shape))
# Out:
# Vaccination aefi data set dimensions : (937, 32)

# %%
#Data cleaning/transforming
#Remove unrelated columns 
Vax_aefi_dataset.drop(['daily_serious_npra', 'daily_nonserious', 'daily_nonserious_npra', 'daily_nonserious_mysj_dose1', 'daily_nonserious_mysj_dose2'], axis=1, inplace=True)

#Create column to sum aefi for dose 1 and 2 
Vax_aefi_dataset['site_pain'] = Vax_aefi_dataset['d1_site_pain'] + Vax_aefi_dataset['d2_site_pain']
Vax_aefi_dataset['site_swelling'] = Vax_aefi_dataset['d1_site_swelling'] + Vax_aefi_dataset['d2_site_swelling']
Vax_aefi_dataset['site_redness'] = Vax_aefi_dataset['d1_site_redness'] + Vax_aefi_dataset['d2_site_redness']
Vax_aefi_dataset['tiredness'] = Vax_aefi_dataset['d1_tiredness'] + Vax_aefi_dataset['d2_tiredness']
Vax_aefi_dataset['headache'] = Vax_aefi_dataset['d1_headache'] + Vax_aefi_dataset['d2_headache']
Vax_aefi_dataset['muscle_pain'] = Vax_aefi_dataset['d1_muscle_pain'] + Vax_aefi_dataset['d2_muscle_pain']
Vax_aefi_dataset['joint_pain'] = Vax_aefi_dataset['d1_joint_pain'] + Vax_aefi_dataset['d2_joint_pain']
Vax_aefi_dataset['weakness'] = Vax_aefi_dataset['d1_weakness'] + Vax_aefi_dataset['d2_weakness']
Vax_aefi_dataset['fever'] = Vax_aefi_dataset['d1_fever'] + Vax_aefi_dataset['d2_fever']
Vax_aefi_dataset['vomiting'] = Vax_aefi_dataset['d1_vomiting'] + Vax_aefi_dataset['d2_site_pain']
Vax_aefi_dataset['chills'] = Vax_aefi_dataset['d1_chills'] + Vax_aefi_dataset['d2_chills']
Vax_aefi_dataset['rash'] = Vax_aefi_dataset['d1_rash'] + Vax_aefi_dataset['d2_rash']

#Remove columns for aefi dose 1 and 2 since the sum have been calculated
Vax_aefi_dataset.drop(['d1_site_pain', 'd1_site_swelling', 'd1_site_redness', 'd1_tiredness', 'd1_headache', 'd1_muscle_pain',
                       'd1_joint_pain', 'd1_weakness', 'd1_fever', 'd1_vomiting', 'd1_chills', 'd1_rash',
                       'd2_site_pain', 'd2_site_swelling', 'd2_site_redness', 'd2_tiredness', 'd2_headache', 'd2_muscle_pain',
                       'd2_joint_pain', 'd2_weakness', 'd2_fever', 'd2_vomiting', 'd2_chills', 'd2_rash',], 
                      axis=1, inplace=True)

# %%
#View the cleaned data set
Vax_aefi_dataset
# Out:
#            date      vaxtype  daily_total  ...  vomiting  chills  rash
# 0    2021-02-25       pfizer            1  ...         0       0     0
# 1    2021-02-26       pfizer            2  ...         0       0     0
# 2    2021-02-27       pfizer            4  ...         0       0     0
# 3    2021-02-28       pfizer           12  ...         0       0     0
# 4    2021-03-01       pfizer           33  ...         0       0     0
# ..          ...          ...          ...  ...       ...     ...   ...
# 932  2022-01-11      sinovac            6  ...         0       0     0
# 933  2022-01-12  astrazeneca            0  ...         0       0     0
# 934  2022-01-12       pfizer           30  ...         2       3     0
# 935  2022-01-12    sinopharm            0  ...         0       0     0
# 936  2022-01-12      sinovac            2  ...         0       0     1
#
# [937 rows x 15 columns]

# %%
#View the dimensions of the cleaned dataset
print('This is the updated data set dimensions after cleaning')
print("Vaccination aefi data set dimensions : {}".format(Vax_aefi_dataset.shape))
# Out:
# This is the updated data set dimensions after cleaning
# Vaccination aefi data set dimensions : (937, 15)

# %%
#View the basic statistic details about the data of the dataset
Vax_aefi_dataset.describe().T
# Out:
#                count         mean          std  ...    50%     75%     max
# daily_total    937.0  1071.235859  1515.487297  ...  275.0  1692.0  8905.0
# site_pain      937.0   736.925293  1136.475905  ...  155.0  1127.0  6905.0
# site_swelling  937.0   170.136606   301.326931  ...   23.0   219.0  3844.0
# site_redness   937.0    55.416222    96.752844  ...    9.0    71.0   929.0
# tiredness      937.0   560.395945   892.633484  ...  138.0   776.0  5918.0
# headache       937.0   494.858058   812.226900  ...  116.0   639.0  5466.0
# muscle_pain    937.0   340.239061   602.022812  ...   76.0   420.0  4305.0
# joint_pain     937.0   219.346852   422.711408  ...   47.0   212.0  2968.0
# weakness       937.0   366.783351   656.388169  ...   89.0   423.0  4564.0
# fever          937.0   342.559232   801.622954  ...   52.0   236.0  5781.0
# vomiting       937.0   160.005336   249.872375  ...   38.0   235.0  3226.0
# ...

# %%
#View the basic statistic details for each aefi for each vaccine type
Vax_aefi_dataset.groupby('vaxtype').describe()
# Out:
#             daily_total                                 ... rash
#                   count         mean          std  min  ...  25%   50%    75%    max
# vaxtype                                                 ...
# astrazeneca       253.0  1533.304348  2081.142177  0.0  ...  0.0   5.0  91.00  233.0
# pfizer            322.0  1318.891304  1332.823580  1.0  ...  4.0  31.0  60.75  195.0
# sinopharm          73.0     0.958904     1.549537  0.0  ...  0.0   0.0   0.00    1.0
# sinovac           289.0   661.138408   989.598962  0.0  ...  1.0   8.0  40.00  219.0
#
# [4 rows x 104 columns]

# %%
#find the sum of NA
Vax_aefi_dataset.isnull().sum()
# Out:
# date             0
# vaxtype          0
# daily_total      0
# site_pain        0
# site_swelling    0
# site_redness     0
# tiredness        0
# headache         0
# muscle_pain      0
# joint_pain       0
# weakness         0
# fever            0
# vomiting         0
# chills           0
# rash             0
# dtype: int64

# %%
#The distribution of the total number of non serious AEFI cases for each Covid19 vaccine
plt.hist(Vax_aefi_dataset['daily_total'][Vax_aefi_dataset['vaxtype'] == 'pfizer'], bins=10, alpha=0.5, label='Pfizer')
plt.hist(Vax_aefi_dataset['daily_total'][Vax_aefi_dataset['vaxtype'] == 'astrazeneca'], bins=10, alpha=0.5, label='Astrazeneca')
plt.hist(Vax_aefi_dataset['daily_total'][Vax_aefi_dataset['vaxtype'] == 'sinopharm'], bins=10, alpha=0.5, label='Sinopharm')
plt.hist(Vax_aefi_dataset['daily_total'][Vax_aefi_dataset['vaxtype'] == 'sinovac'], bins=10, alpha=0.5, label='Sinovac')
plt.xlabel("daily_total")
plt.ylabel("Number of aefi cases")
plt.legend(loc='upper right')
plt.show()

# %%
#Density plot showing the distribution of the total number of non serious AEFI cases for each vaccine
names = ['pfizer', 'astrazeneca', 'sinopharm', 'sinovac']
for i in names:
  (Vax_aefi_dataset['daily_total'][Vax_aefi_dataset['vaxtype'] == i]).plot(kind = 'density')
  plt.title(i)
  plt.show()

# %%
#Total of each non serious AEFI case for each vaccine
Vax_aefi_dataset[Vax_aefi_dataset.vaxtype == 'pfizer'].iloc[:, 3:15].sum().plot(kind="bar")
plt.xlabel("types of aefi")
plt.ylabel("Number of aefi cases")
plt.title("Pfizer")
plt.show() 
Vax_aefi_dataset[Vax_aefi_dataset.vaxtype == 'astrazeneca'].iloc[:, 3:15].sum().plot(kind="bar")
plt.xlabel("types of aefi")
plt.ylabel("Number of aefi cases")
plt.title("Astrazeneca")
plt.show() 
Vax_aefi_dataset[Vax_aefi_dataset.vaxtype == 'sinopharm'].iloc[:, 3:15].sum().plot(kind="bar")
plt.xlabel("types of aefi")
plt.ylabel("Number of aefi cases")
plt.title("Sinopharm")
plt.show() 
Vax_aefi_dataset[Vax_aefi_dataset.vaxtype == 'sinovac'].iloc[:, 3:15].sum().plot(kind="bar")
plt.xlabel("types of aefi")
plt.ylabel("Number of aefi cases")
plt.title("Sinovac")
plt.show()

# %%
#Calculate the sum of each aefi for each vaccine 
Vax_aefi_dataset.groupby(['vaxtype']).sum()
# Out:
#              daily_total  site_pain  site_swelling  ...  vomiting  chills   rash
# vaxtype                                             ...
# astrazeneca       387926     291811          72496  ...     54708  187712  10875
# pfizer            424683     309555          76218  ...     68529   40625  13657
# sinopharm             70         41              4  ...        12       6      9
# sinovac           191069      89092          10700  ...     26676   20545   8633
#
# [4 rows x 13 columns]

# %%
#The summary of each non serious AEFI cases by vaccine type
Vax_aefi_dataset.groupby(['vaxtype']).sum().iloc[:, 1:13].plot.bar(stacked=True).legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.ylabel("Number of aefi cases")
plt.show()

# %% [markdown]
# #ICU Dataset

# %%
# importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# importing ICU  dataset from GitHub
dataset_ICU = pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/icu.csv')

# %%
# exploration on variable of the datasets
dataset_ICU.head()
# Out:
#          date            state  ...  vent_used  vent_port_used
# 0  2020-03-24            Johor  ...          8               0
# 1  2020-03-24            Kedah  ...         19               0
# 2  2020-03-24         Kelantan  ...         26               0
# 3  2020-03-24           Melaka  ...         13               5
# 4  2020-03-24  Negeri Sembilan  ...          1               6
#
# [5 rows x 16 columns]

# %%
# describe icu dataset
dataset_ICU.describe()
# Out:
#            beds_icu  beds_icu_rep  ...     vent_used  vent_port_used
# count  10215.000000  10215.000000  ...  10215.000000    10215.000000
# mean      49.429956     34.578365  ...     53.946353        2.313363
# std       35.867644     39.163946  ...     46.686612        6.503286
# min        5.000000      0.000000  ...      0.000000        0.000000
# 25%       23.000000      5.000000  ...     23.000000        0.000000
# 50%       47.000000     21.000000  ...     41.000000        0.000000
# 75%       65.000000     60.000000  ...     76.000000        0.000000
# max      247.000000    227.000000  ...    402.000000       75.000000
#
# [8 rows x 14 columns]

# %%
#selecting rows based on state
state1 = dataset_ICU['state'].value_counts()
state2 = dataset_ICU.loc[state1]
print(state2)
# Out:
#            date   state  beds_icu  ...  vent_noncovid  vent_used  vent_port_used
# 663  2020-05-07  Melaka        52  ...              0         34               0
# 663  2020-05-07  Melaka        52  ...              0         34               0
# 663  2020-05-07  Melaka        52  ...              0         34               0
# 663  2020-05-07  Melaka        52  ...              0         34               0
# 663  2020-05-07  Melaka        52  ...              0         34               0
# 663  2020-05-07  Melaka        52  ...              0         34               0
# 663  2020-05-07  Melaka        52  ...              0         34               0
# 663  2020-05-07  Melaka        52  ...              0         34               0
# 663  2020-05-07  Melaka        52  ...              0         34               0
# 663  2020-05-07  Melaka        52  ...              0         34               0
# 663  2020-05-07  Melaka        52  ...              0         34               0
# ...

# %%
# total of covid cases in ICU for each state
state_icu_covid =   dataset_ICU.groupby('state').icu_covid.sum()
print(state_icu_covid)
# Out:
# state
# Johor                25704
# Kedah                19109
# Kelantan             13695
# Melaka               12972
# Negeri Sembilan      10931
# Pahang                8218
# Perak                17417
# Perlis                1313
# Pulau Pinang         13387
# Sabah                33850
# Sarawak              23507
# Selangor             66214
# Terengganu            5606
# W.P. Kuala Lumpur    26612
# W.P. Labuan           1317
# W.P. Putrajaya        2161
# Name: icu_covid, dtype: int64

# %%
# establish new dataframe 
# column of the dataframe : state, covid_icu, total_bed_icu
column = ['state','beds_icu_total','icu_covid']
icu_bed_covid = dataset_ICU[column]
print(icu_bed_covid)
# Out:
#                    state  beds_icu_total  icu_covid
# 0                  Johor              32          0
# 1                  Kedah              35          2
# 2               Kelantan              39          1
# 3                 Melaka              26          0
# 4        Negeri Sembilan              18          0
# ...                  ...             ...        ...
# 10210           Selangor             195         32
# 10211         Terengganu              61         12
# 10212  W.P. Kuala Lumpur              98         14
# 10213        W.P. Labuan              12          2
# 10214     W.P. Putrajaya              20          0
#
# [10215 rows x 3 columns]

# %%
df_icu_covid = pd.DataFrame(icu_bed_covid)
print(df_icu_covid)
# Out:
#                    state  beds_icu_total  icu_covid
# 0                  Johor              32          0
# 1                  Kedah              35          2
# 2               Kelantan              39          1
# 3                 Melaka              26          0
# 4        Negeri Sembilan              18          0
# ...                  ...             ...        ...
# 10210           Selangor             195         32
# 10211         Terengganu              61         12
# 10212  W.P. Kuala Lumpur              98         14
# 10213        W.P. Labuan              12          2
# 10214     W.P. Putrajaya              20          0
#
# [10215 rows x 3 columns]

# %%
# Barplot on total icu covid-19 cases in each state
plt.barh(df_icu_covid['state'], df_icu_covid['icu_covid'])
plt.title('total ICU covid 19 cases in each state')
plt.ylabel('ICU covid-19 cases')
plt.xlabel('state')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# *Time series analysis*

# %%
from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# %%
# Import as dataset_ICU
dataset_ICU = pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/icu.csv')
dataset_ICU.head()
# Out:
#          date            state  ...  vent_used  vent_port_used
# 0  2020-03-24            Johor  ...          8               0
# 1  2020-03-24            Kedah  ...         19               0
# 2  2020-03-24         Kelantan  ...         26               0
# 3  2020-03-24           Melaka  ...         13               5
# 4  2020-03-24  Negeri Sembilan  ...          1               6
#
# [5 rows x 16 columns]

# %%
#import it as a pandas Series with the date as index
ser = pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/icu.csv', parse_dates=['date'], index_col='date')
ser.head()
# Out:
#                       state  beds_icu  ...  vent_used  vent_port_used
# date                                   ...
# 2020-03-24            Johor        10  ...          8               0
# 2020-03-24            Kedah        35  ...         19               0
# 2020-03-24         Kelantan        39  ...         26               0
# 2020-03-24           Melaka        26  ...         13               5
# 2020-03-24  Negeri Sembilan        18  ...          1               6
#
# [5 rows x 15 columns]

# %%
import matplotlib.pyplot as plt

# %%
# import dataset icu from github as df
df = pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/icu.csv', parse_dates=['date'], index_col='date')

# %%
df.head()
# Out:
#                       state  beds_icu  ...  vent_used  vent_port_used
# date                                   ...
# 2020-03-24            Johor        10  ...          8               0
# 2020-03-24            Kedah        35  ...         19               0
# 2020-03-24         Kelantan        39  ...         26               0
# 2020-03-24           Melaka        26  ...         13               5
# 2020-03-24  Negeri Sembilan        18  ...          1               6
#
# [5 rows x 15 columns]

# %%
df.tail()
# Out:
#                         state  beds_icu  ...  vent_used  vent_port_used
# date                                     ...
# 2022-01-15           Selangor       163  ...         86              34
# 2022-01-15         Terengganu        40  ...         26              13
# 2022-01-15  W.P. Kuala Lumpur        75  ...         66              14
# 2022-01-15        W.P. Labuan         5  ...          1               0
# 2022-01-15     W.P. Putrajaya        14  ...          6               0
#
# [5 rows x 15 columns]

# %%
# Draw plot
def plot_df(df, x, y, title="", xlabel='Date', ylabel='icu_covid', dpi=200):
    plt.figure(figsize=(20,10), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

# %%
# Plot for time series 
plot_df(df, x=df.index, y=df.icu_covid, title='Time series on ICU Covid-19 Cases in Malaysia from Mac 2020')
